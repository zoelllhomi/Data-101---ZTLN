# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 2
# ---------------------------------------
#
# GOALS:
#
# 1. Start using Python
# 2. Start looking at Data!
#
# ----------------------------------------------------------
#
# This homework has **TWO** warm-up problems and **FOUR** problems.

# %% [markdown]
# ## Hello World!
#
# ### Warm up Problem 1
#
# Write python code that will print your name and run the cell.

# %%
print("Hello Zoell")
# Out:
# Hello Zoell

# %% [markdown]
# ## Installing Modules
#
# ### Warm up Problem 2
#
# Install the modules that you will need to run the rest of the code. You can copy and paste the commands from the class notes. This might take a minute or two to run... go get a cup of coffee :)

# %%
# !conda install -y numpy
# !conda install -y pandas
# !conda install -y matplotlib
# !conda install -y plotly
# !conda install -y itables
# !conda install -y statsmodels
# !conda install -y -c conda-forge python-kaleido

# %% [markdown]
# ## Let's do some Data Science.
#
# We will explore some data about how countries vote at the United Nations General Assembly. You should follow along with the notes and/or class video.
#
# I am breaking this into parts and having you copy and paste the code so you can start to identify what the different parts of the code do.

# %% [markdown]
# -------------------------------
# ### Importing Packages:
# -------------------------------
#
# Every time we start a new project we will import the packages that will help us do the analysis. Copy and paste all of the imports in the cell below.
#
# * numpy = mathematical and number packages for python
# * pandas = pretty tables, dataframes, and data analysis packages
# * matplotlib.pyplot = nice looking graphs
# * plotly = nice looking graphs.
# * itables = pretty looking tables that have a search bar

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.default='colab'

from itables import show

# %% [markdown]
# -------------------------------
# ### Get the Data:
# -------------------------------
#
# We will practice all sorts of ways to get data into our notebooks. When you use Pandas (pd) to read a csv:
#
#     DF = pd.read_csv(file_location)
#
# you are basically reading in a spreadsheet (Excel). The data for today is stored on my website.
#
# It might take a minute for the data to load.

# %%
# Note this takes about a minute to run
file_location = 'https://joannabieri.com/introdatascience/data/unvotes.csv'
DF = pd.read_csv(file_location)
years = [int(d.split('-')[0]) for d in DF['date']]
DF['year'] = years
DF = DF.drop('Unnamed: 0',axis=1)

# %% [markdown]
# -------------------------------
# ### Initial Data Exploration:
# -------------------------------
# -------------------------------
# ### Show the Data:
# -------------------------------
#
# We want to look at what we have. The data is now represented by the variable DF.

# %%
display(DF)
# Out:
#         rcid             country country_code     vote  session  \
# 0          6       United States           US       no        1
# 1          6              Canada           CA       no        1
# 2          6                Cuba           CU      yes        1
# 3          6  Dominican Republic           DO  abstain        1
# 4          6              Mexico           MX      yes        1
# ...      ...                 ...          ...      ...      ...
# 857873  9101           Venezuela           VE      yes       74
# 857874  9101             Vietnam           VN      yes       74
# 857875  9101               Yemen           YE      yes       74
# 857876  9101              Zambia           ZM      yes       74
# 857877  9101            Zimbabwe           ZW      yes       74
#
#         importantvote        date        unres  amend  para  \
# 0                 0.0  1946-01-04      R/1/107    0.0   0.0
# 1                 0.0  1946-01-04      R/1/107    0.0   0.0
# 2                 0.0  1946-01-04      R/1/107    0.0   0.0
# 3                 0.0  1946-01-04      R/1/107    0.0   0.0
# 4                 0.0  1946-01-04      R/1/107    0.0   0.0
# ...               ...         ...          ...    ...   ...
# 857873            NaN  2019-12-03  A/RES/74/12    NaN   NaN
# 857874            NaN  2019-12-03  A/RES/74/12    NaN   NaN
# 857875            NaN  2019-12-03  A/RES/74/12    NaN   NaN
# 857876            NaN  2019-12-03  A/RES/74/12    NaN   NaN
# 857877            NaN  2019-12-03  A/RES/74/12    NaN   NaN
#
#                                                     short  \
# 0                             DECLARATION OF HUMAN RIGHTS
# 1                             DECLARATION OF HUMAN RIGHTS
# 2                             DECLARATION OF HUMAN RIGHTS
# 3                             DECLARATION OF HUMAN RIGHTS
# 4                             DECLARATION OF HUMAN RIGHTS
# ...                                                   ...
# 857873  Division for Palestinian Rights of the Secreta...
# 857874  Division for Palestinian Rights of the Secreta...
# 857875  Division for Palestinian Rights of the Secreta...
# 857876  Division for Palestinian Rights of the Secreta...
# 857877  Division for Palestinian Rights of the Secreta...
#
#                                                     descr short_name  \
# 0       TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM...         hr
# 1       TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM...         hr
# 2       TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM...         hr
# 3       TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM...         hr
# 4       TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM...         hr
# ...                                                   ...        ...
# 857873  Division for Palestinian Rights of the Secreta...         me
# 857874  Division for Palestinian Rights of the Secreta...         me
# 857875  Division for Palestinian Rights of the Secreta...         me
# 857876  Division for Palestinian Rights of the Secreta...         me
# 857877  Division for Palestinian Rights of the Secreta...         me
#
#                        issue  year
# 0               Human rights  1946
# 1               Human rights  1946
# 2               Human rights  1946
# 3               Human rights  1946
# 4               Human rights  1946
# ...                      ...   ...
# 857873  Palestinian conflict  2019
# 857874  Palestinian conflict  2019
# 857875  Palestinian conflict  2019
# 857876  Palestinian conflict  2019
# 857877  Palestinian conflict  2019
#
# [857878 rows x 15 columns]

# %% [markdown]
# ### Problem 1
#
# Do some initial exploration of this data and write about it in the markdown cell below.
#
# * How man columns are there?
# * What do the columns represent?
# * What countries are there?
# * Can you search for a country you are interested in?
# * How many rows are there?
# * What other observations do you have?

# %% [markdown]
# - 15
# - Countries and the decleration of human rights
# - U.S, Canada, Cuba, Dominican Republic, Mexico, Venezuela, Vietnam, Yemen, Zambia and Zimbabwe
# - Zambia
# - 857878
# - Their are a lot of rows and coulums

# %% [markdown]
# -------------------------------
# ### Make Python Explore the Data!:
# -------------------------------
#
# Copy and paste the command that will show you a list of the counties:

# %%
# Python can list all the different countries:
country_list = list(DF['country'].unique())

# Show the data in a nice way
show(pd.DataFrame(country_list,columns=['country']))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_4a9e6b2e_a68e_461f_82cd_89aa832dbb87"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_4a9e6b2e_a68e_461f_82cd_89aa832dbb87:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "classes": ["display", "nowrap"], "order": [], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>country</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"United States\"], [\"Canada\"], [\"Cuba\"], [\"Dominican Republic\"], [\"Mexico\"], [\"Guatemala\"], [\"Honduras\"], [\"El Salvador\"], [\"Nicaragua\"], [\"Panama\"], [\"Colombia\"], [\"Venezuela\"], [\"Ecuador\"], [\"Peru\"], [\"Brazil\"], [\"Bolivia\"], [\"Paraguay\"], [\"Chile\"], [\"Argentina\"], [\"Uruguay\"], [\"United Kingdom\"], [\"Netherlands\"], [\"Belgium\"], [\"Luxembourg\"], [\"France\"], [\"Poland\"], [\"Czechoslovakia\"], [\"Yugoslavia\"], [\"Greece\"], [\"Russia\"], [\"Ukraine\"], [\"Belarus\"], [\"Norway\"], [\"Denmark\"], [\"Liberia\"], [\"Ethiopia\"], [\"South Africa\"], [\"Iran\"], [\"Turkey\"], [\"Iraq\"], [\"Egypt\"], [\"Syria\"], [\"Lebanon\"], [\"Saudi Arabia\"], [\"Taiwan\"], [\"India\"], [\"Philippines\"], [\"Australia\"], [\"New Zealand\"], [\"Costa Rica\"], [\"Haiti\"], [\"Sweden\"], [\"Iceland\"], [\"Afghanistan\"], [\"Yemen Arab Republic\"], [\"Pakistan\"], [\"Thailand\"], [\"Myanmar (Burma)\"], [\"Israel\"], [\"Indonesia\"], [\"Hungary\"], [\"Jordan\"], [\"Sri Lanka\"], [\"Spain\"], [\"Romania\"], [\"Ireland\"], [\"Portugal\"], [\"Austria\"], [\"Italy\"], [\"Albania\"], [\"Bulgaria\"], [\"Finland\"], [\"Morocco\"], [\"Tunisia\"], [\"Libya\"], [\"Sudan\"], [\"Nepal\"], [\"Cambodia\"], [\"Laos\"], [\"Japan\"], [\"Ghana\"], [\"Malaysia\"], [\"Guinea\"], [\"Cyprus\"], [\"Mali\"], [\"Senegal\"], [\"Benin\"], [\"Niger\"], [\"C\\u00f4te d\\u2019Ivoire\"], [\"Burkina Faso\"], [\"Togo\"], [\"Cameroon\"], [\"Nigeria\"], [\"Gabon\"], [\"Central African Republic\"], [\"Chad\"], [\"Congo - Brazzaville\"], [\"Somalia\"], [\"Madagascar\"], [\"Congo - Kinshasa\"], [\"Mauritania\"], [\"Sierra Leone\"], [\"Mongolia\"], [\"Tanzania\"], [\"Jamaica\"], [\"Trinidad &amp; Tobago\"], [\"Uganda\"], [\"Burundi\"], [\"Rwanda\"], [\"Algeria\"], [\"Kuwait\"], [\"Kenya\"], [\"Zanzibar\"], [\"Malta\"], [\"Zambia\"], [\"Maldives\"], [\"Malawi\"], [\"Singapore\"], [\"Guyana\"], [\"Gambia\"], [\"Lesotho\"], [\"Barbados\"], [\"Botswana\"], [\"Yemen People's Republic\"], [\"Mauritius\"], [\"Equatorial Guinea\"], [\"Eswatini\"], [\"Fiji\"], [\"Bahrain\"], [\"Qatar\"], [\"China\"], [\"Oman\"], [\"United Arab Emirates\"], [\"Bhutan\"], [\"Federal Republic of Germany\"], [\"German Democratic Republic\"], [\"Bahamas\"], [\"Bangladesh\"], [\"Grenada\"], [\"Guinea-Bissau\"], [\"Cape Verde\"], [\"S\\u00e3o Tom\\u00e9 &amp; Pr\\u00edncipe\"], [\"Mozambique\"], [\"Comoros\"], [\"Papua New Guinea\"], [\"Suriname\"], [\"Angola\"], [\"Djibouti\"], [\"Vietnam\"], [\"Samoa\"], [\"Seychelles\"], [\"St. Lucia\"], [\"Solomon Islands\"], [\"Zimbabwe\"], [\"Vanuatu\"], [\"Antigua &amp; Barbuda\"], [\"Belize\"], [\"St. Vincent &amp; Grenadines\"], [\"Dominica\"], [\"St. Kitts &amp; Nevis\"], [\"Brunei\"], [\"Liechtenstein\"], [\"Namibia\"], [\"Germany\"], [\"Estonia\"], [\"Latvia\"], [\"Lithuania\"], [\"Yemen\"], [\"North Korea\"], [\"South Korea\"], [\"Marshall Islands\"], [\"Micronesia (Federated States of)\"], [\"Croatia\"], [\"Slovenia\"], [\"Moldova\"], [\"San Marino\"], [\"Armenia\"], [\"Azerbaijan\"], [\"Bosnia &amp; Herzegovina\"], [\"Kazakhstan\"], [\"Tajikistan\"], [\"Turkmenistan\"], [\"Kyrgyzstan\"], [\"Andorra\"], [\"Czechia\"], [\"Slovakia\"], [\"North Macedonia\"], [\"Monaco\"], [\"Georgia\"], [\"Eritrea\"], [\"Uzbekistan\"], [\"Palau\"], [\"Tonga\"], [\"Nauru\"], [\"Tuvalu\"], [\"Kiribati\"], [\"Switzerland\"], [\"Timor-Leste\"], [\"Montenegro\"], [\"South Sudan\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# Copy and paste the command that will count up the number of countries:

# %%
# Python can count up the number of countries.
# Find the length of the list
print(len(country_list))
# Out:
# 200

# %% [markdown]
# ### Problem 2
#
# Try writing some code for your self. Above we found a countries list by focusing on the column named 'country'. See if you can redo that same code but change it to focus on the column named 'issue'.
#
# What do I expect here:
#
# * First copy and past the code from above
# * Then change that code slightly
# * Run the cell to see if it worked

# %%
# Optional - Make a nice print statement
print(f'There are {len(country_list)} in our data set!')
# Out:
# There are 200 in our data set!

# %% [markdown]
# -------------------------------
# ### Data Visualization:
# -------------------------------
#
# Now we will select three countries that we are interested in and see how their votes have changed over time. Below you should see code that selects: Turkey, United States, and United Kingdom.
#
# **IMPORTANT** These have to be spelled and capitalized exactly like they are in the data. Python is unforgiving of typos!
#
# You can just run the cell below - assuming you have done all the parts above!

# %%
countries = ['Nepal', 'France', 'Brazil']
issues = list(DF['issue'].unique())
c_groups = DF.groupby(['country','issue'])
print(issues)
# Out:
# ['Human rights', 'Economic development', 'Colonialism', 'Palestinian conflict', 'Arms control and disarmament', 'Nuclear weapons and nuclear material']

# %% [markdown]
# Now that we have our focus countries, we can make pretty pictures.
#
# You can just run the cell below - assuming you have done all the parts above!

# %%
def make_plot(countries,issue):
    '''
    A Python function that takes in the list of countries and issues and makes
    a scatter plot of each issue with a trendline for each country.
    '''
    x_data = []
    y_data = []
    c_data = []
    for cntry in countries:
        my_group = c_groups.get_group((cntry,issue))
        for y in my_group['year'].unique():
            x_data.append(y)
            tot_yes = sum(my_group[my_group['year']==y]['vote']=='yes')
            percent_yes = tot_yes/len(my_group[my_group['year']==y])*100
            y_data.append(percent_yes)
            c_data.append(cntry)

    fig = px.scatter(x=x_data, y=y_data,color=c_data,trendline="lowess",labels={"color": "Country"})

    fig.update_layout(
        title={
            'text': issue + '<br>',
            'y':0.9,
            'x':0.5,
            'xanchor': 'center',
            'yanchor': 'top'})
    fig.update_yaxes(title_text="% Yes")
    fig.update_xaxes(title_text="Year")
    fig.show()
    
for iss in issues:
    make_plot(countries,iss)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="fb193a45-e65d-4e89-b9a9-7bb1266a6c2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fb193a45-e65d-4e89-b9a9-7bb1266a6c2b")) {                    Plotly.newPlot(                        "fb193a45-e65d-4e89-b9a9-7bb1266a6c2b",                        [{"hovertemplate":"Country=Nepal\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nepal","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Nepal","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"pAemB6cHqQeqB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1gfVB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Nepal\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nepal","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Nepal","showlegend":false,"x":{"dtype":"i2","bdata":"pAemB6cHqQeqB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"1R74afm8S0CbVgDgJ8FMQFN\u002fLIxTQU1AJl6PG2s9TkC0c0lUBblOQBz\u002fItQDEVBAIyRs+dhLUEAdOwDSRYZQQNfD+6R9wFBAHcUWxsf6UEAXiBuhczVRQJSS3ebccFFA\u002fOQ\u002fZGGtUUASXONLVetRQAc8rzjvKlJAzwQeSBJsUkCx+VVL561SQBYL3SCK7lJANzgTMxgkU0CmHNF\u002fy1JTQAwskomPeFNAmkub4VqcU0DjZvzke69TQPjNi9IUu1NAKkJwUZzHU0CCKrrn98hTQJcQt3r8x1NAfkviwwPHU0DDRfA1OcdTQJaNvb5ayVNA6ymopabNU0BH7gai99NTQMMR9BXi21NA1h87vtLkU0AXNkpZ7+1TQBL79VwC9lNACdQk1Pz7U0A1cWiLCf9TQJ08foA0\u002f1NAZTQtidT8U0AFoIppp\u002fhTQEhYMqasAVRAouGdmcIIVEDjwe\u002fr3A1UQF8\u002fISDsEVRAKvJny7QVVED8OO2TuRlUQKjzIGxWHlRAJK4WesYjVEDtj9jpKipUQDj5rcqQMVRAoiDAPvc5VECiNJvIUUNUQMsMI+eOTVRAzGkMYpVYVEAdAKa7Q2RUQG\u002fD6fx1cFRAlrGFyQd9VEAGRM0u2IlUQIfu1ZXFllRA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=France\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mgecB50HngegB6EHogejB6QHpgenB6kHqgetB64HrwewB7EHsgezB7QHtQe2B7cHuAe5B7oHuwe8B70Hvge\u002fB8AHwQfCB8MHxAfFB8YHxwfIB8kHygfLB8wHzQfOB88H0AfRB9IH0wfUB9YH1QfXB9gH2QfaB9sH3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"\\u002fzPM\u002fzTkByHMdxHMdLQAAAAAAAAElAWchCFrKQQ0AAAAAAAABKQAAAAAAAAEhAIQtZyEIWSkDbtm3btm1FQI7jOI7jOEZAAAAAAAAAREBDeQ3lNZQ\u002fQKuqqqqqqkpARRdddNFFS0Dbtm3btm1FQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=France\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"col ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="ce56c21e-810a-4516-969b-e0e396770213" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ce56c21e-810a-4516-969b-e0e396770213")) {                    Plotly.newPlot(                        "ce56c21e-810a-4516-969b-e0e396770213",                        [{"hovertemplate":"Country=Nepal\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nepal","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Nepal","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"pAelB6YHpwepB6oHqweuB68HsAexB7IHswe0B7UHtge3B7gHuQe7B7oHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAWUAAAAAAAABZQAAAAAAAAFlAAAAAAAAASUC66KKLLrpGQKqqqqqqqlBAAAAAAADAUkBWVVVVVdVUQAAAAAAAAFRAqqqqqqqqUEAAAAAAAABZQAAAAAAAAFlAAAAAAAAAWUDmnkZY7mlWQA8PDw8PD1ZAAAAAAAAAVEAAAAAAAABZQAAAAAAAAFlAAAAAAAAAWUAAAAAAAABXQHrTm970plRAAAAAAADgVUDzPM\..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Nepal\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nepal","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Nepal","showlegend":false,"x":{"dtype":"i2","bdata":"pAelB6YHpwepB6oHqweuB68HsAexB7IHswe0B7UHtge3B7gHuQe6B7sHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"VjQUODBtVkAhYak7aW5WQGM0DiwvcFZAl3MDDWVyVkB8BIJ\u002fbXdWQCsvjx3eeVZAVTDcEP57VkDuV73WPn9WQPFFCmMIf1ZAFbiJnBx+VkCd\u002f5vujXxWQPGeDtONelZAyVYzVmZ4VkD2vLF1hnZWQM2QNo+ldVZAUtUSrg13VkBUyNGE\u002fnxWQBtny62iilZAxNxihGOhVkBiDEcxP69WQKXoPAsHuFZAyIb\u002fF\u002fO6VkBObYS5l7hWQHi5rbN3slZAhR\u002fu9tGqVkAQOoiCOaRWQMHHoGRMmlZA50CSVXmWVkClVNwYaJhWQGSspqDQn1ZAunKCW7KrVkAK\u002f+OIa7pWQKAuIu9vylZAwwINeT\u002faVkAMJMFhz+hWQP5AlXnN9VZAiAYz8n0BV0B5LSXm1wtXQMvmj6nsFFdAux8LQf0cV0A3de7L4CRXQJdShd+ULVdA\u002fUAfeWE5V0BPKjU6X0dXQEzb3ysYV1dArLsLvwBoV0D4Gb1ZpXlXQFGuDwCqi1dAohJCgMedV0CuhGB1zK9XQJKwoHWSwVdAufY40P3SV0CkGzS1+eNXQKBi\u002fQF+9FdAwF50v4wEWEBmFgn5LBRYQOGJ\u002fa1lI1hAOLuYJkEyWED7XgAByUBYQJu4d8AJT1hAb3SYVRFdWEA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=France\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mgebB5wHnQeeB6AHoQeiB6QHpQemB6cHqQeqB6sHrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuwe6B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=France\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"France","showlegend":false,"x":{"dtype":"i2","bdata":"mgebB5wHnQeeB6AHoQeiB6QHpQemB6cHqQeqB6sHrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"umb3WhVSUUBnJGVN3A5RQOa2BEy8y1BAlZnV\u002fauIUEDQ90gzq0VQQDyLMKozgE9ARmENdW\u002f7TkBdJc0YkHdOQDnWxJBac01AaO0Ot0fzTECfCnq2nnRMQCgowLZH90tAjIT5fcL\u002 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="56770875-a07e-495c-a1cf-65e67d87f195" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("56770875-a07e-495c-a1cf-65e67d87f195")) {                    Plotly.newPlot(                        "56770875-a07e-495c-a1cf-65e67d87f195",                        [{"hovertemplate":"Country=Nepal\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nepal","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Nepal","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"pQekB6cHqAepB6oHqwetB64HrwewB7EHsgezB7QHtQe2B7cHuAe5B7oHuwe8B70Hvge\u002fB8AHwQfCB8MHxAfFB8YHxwfIB8kHygfLB8wHzQfOB88H0AfRB9IH0wfUB9UH1gfXB9gH2QfaB9sH3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"juM4juM4RkAAAAAAAABJQLITO7ETO1NAddFFF110VEBVVVVVVVVHQLdt27Zt21FAAAAAAAAAWUAAAAAAAABZQAAAAAAAAFlAdmIndmInVUC66KKLLrpWQKuqqqqqKk1AHh4eHh4eU0DDMAzDMAxTQAAAAAAA4FVAnN70pje9VUCqqqqqqqpQQOh5nud5nlZA5TWU11BeVkDHcRzHcZxXQAAAAAAAwFJAz\u002fM8z\u002fM8VEAAAAAAAOBVQB4eHh4eHlNAnN70pje9VUAAAAAAAABZQN\"},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Nepal\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nepal","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Nepal","showlegend":false,"x":{"dtype":"i2","bdata":"pAelB6cHqAepB6oHqwetB64HrwewB7EHsgezB7QHtQe2B7cHuAe5B7oHuwe8B70Hvge\u002fB8AHwQfCB8MHxAfFB8YHxwfIB8kHygfLB8wHzQfOB88H0AfRB9IH0wfUB9UH1gfXB9gH2QfaB9sH3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"RQKUlMrkUkAx06RRQwdTQEcCR6hRTFNAHxiOCOxuU0DdXnMolpFTQLAlrxFMtFNAGlI\u002fagrXU0AoV0rYvBxUQNb\u002f6KHEP1RAcZgxdvliVEB5KXT9ZIZUQG+EMzYLqlRAmeYNsuXNVEDcVoBz6vFUQFdAJ2MWFlVAKJwD2G86VUDUnbvq+15VQKFPicy\u002fg1VAw3SyMtCoVUAyuVPIZM5VQO71q34q+FVAgWkgDJoiVkCM4ceQM01WQHMQY2Vjd1ZAhtig2rSgVkBMOUCTJslWQHpT7k\u002fo8FZAlB1kqyMZV0CAe9Gmk0BXQPNcXvYNZ1dAdzoRtiqMV0AvyDKYrK9XQMdo7Ymh0VdAMXVEhEfyV0Da4GWRqhFYQB\u002fy2QR4L1hA7WNlS05LWEDEmU+TuGRYQG2FrsY7e1hAaCNqBpmOWEBL2f+by55YQBJdvHssrFhADSRQetWxWEAnqVgUc7dYQF4om2r6vFhAKrI\u002fU1rCWEDnAOmYhcdYQJwhMNx0zFhAWVmNGCXRWEDSmeoBl9VYQAa2wgTQ2VhAAYqi29bdWEDdQrzBtOFYQIS97Cdy5VhADYlODhbpWEAlipVHpuxYQEqn5qcn8FhARfwhKJ7zWEAJJQMDDfdYQOJ2Sc92+lhApR25mN39WEDyz+34QgFZQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=France\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mgebB5wHnQeeB58HoAehB6IHowelB6QHpweoB6kHqgerB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=France\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#EF553B","symbol":"circle"},"mo ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="bfd882b1-e81b-4710-b785-0fed3c479a39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bfd882b1-e81b-4710-b785-0fed3c479a39")) {                    Plotly.newPlot(                        "bfd882b1-e81b-4710-b785-0fed3c479a39",                        [{"hovertemplate":"Country=Nepal\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nepal","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Nepal","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"pQekB6kHqgerB68HsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAWUAAAAAAAABZQAAAAAAAwEJAAAAAAAAAWUAAAAAAAAAAAE\..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Nepal\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nepal","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Nepal","showlegend":false,"x":{"dtype":"i2","bdata":"pAelB6kHqgerB68HsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"xv2QxZsLP0BM\u002fory4p1AQNfUvmSl80RAPpEItooFRkCq98w\u002f0RVHQHrDOyCUSEtATO5csBZcTUDEHIE1nWVOQMdVcSHOb09Ao3eyrsY9UECigsL\u002fB8VQQJfBf3x3TlFATaxuAwrbUUB2HrMohmtSQFMrksku\u002f1JA4nAavWCCU0CmvybG1vhTQNwO9f00aFRAbX8\u002fRCS9VEBxTD4sVglVQPkGe3SYUVVAD8JytJmWVUDJe\u002fMfHt1VQJ\u002fCb1FuHVZA97by7GphVkA1g6izJ51WQAVC3fRC1lZAPtdS\u002fY4MV0BT+HAdwj9XQLKDlPCYb1dAyHbs+wScV0BHBIEfR8VXQFgp974X61dA1m851kANWEAhBt42KyxYQPvgYTqOSFhAuCp+zu5iWEAPZHqtT3tYQPCkyxgokVhApcKxF8ebWECtx9wCSaRYQN\u002fZPPX2q1hA1Dbl7UKzWEAWjZuBRLpYQNWAth37wFhATGGoPGHHWEAihej1cM1YQPJ7Y90k01hAYS3kEnjYWEDvLIIvZt1YQGevBjTr4VhA9DcsewPmWEBEEWisq+lYQH3gjqvg7FhAa52Lz6DvWECMbJHC8PFYQOAPP8za81hA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=France\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mwecB50HngegB6UHpAepB6oHqwetB68HsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"t23btm3bUUB10UUXXXRUQNu2bdu2bVVAAAAAAAAAWUCqqqqqqqpAQAAAAAAAAAAAAAAAAAAAAAAAAAAAAMBCQAAAAAAAAFlAAAAAAAAAWUAAAAAAAABZQE\\u002fM8z\u002fM8VEBZyEIWspBTQAAAAAAAwFJAwzAMwzAMU0C8hvIaymtSQK+hvIbyGlFAAAAAAAAAVEAAAAAAAIBRQLyG8hrKa1JAHh4eHh4eU0AeHh4eHh5TQAAAAAAAwFJAlpaWlpaWVEAeHh4eHh5TQAAAAAAAwFJAAAAAAAAAVEBVVVVVVVVSQOzETuzETlFAAAAAAAAAVEAAAAAAAMBSQLdt27Zt21FA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=France\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"France","showlegend":fal ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="475ab141-7b5d-4e23-b57c-a6ac711e29d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("475ab141-7b5d-4e23-b57c-a6ac711e29d5")) {                    Plotly.newPlot(                        "475ab141-7b5d-4e23-b57c-a6ac711e29d5",                        [{"hovertemplate":"Country=Nepal\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nepal","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Nepal","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"pAelB6YHpweoB6kHqgerB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuwe6B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"...\u002f0pje96VdAVlVVVVX1V0C96U1vetNWQMdxHMdxnFdA8zzP8zzPV0DzPM\u002fzPM9XQJIkSZIkSVhA9zTCck8jWEAAAAAAAABZQAAAAAAAAFlA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Nepal\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nepal","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Nepal","showlegend":false,"x":{"dtype":"i2","bdata":"pAelB6YHpweoB6kHqgerB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"A711RfldWUB6MBJt\u002f1BZQDuIximdQ1lA6KvA4M41WUCSZoV+kSdZQFOxEhvkGFlAKV2go8oJWUCyEkPmT\u002fpYQLWSY59v2lhAJeaQhSvKWEA4MTK2yLlYQMJ3tMFbqVhA9tFw6vmYWEBpUi0ruIhYQO28\u002fkepeFhA49XP2dloWECEoWExSFlYQK9h1nPUSVhAQ0CGwiY6WECU+DlWnylYQNZfjUPoG1hAOD5JRGAPWEBawuQpxwNYQFPOXSL6+FdArlmQdf3uV0AG6fLk6uVXQAKImLDj3VdAaW3v4wPXV0BM2OXpJsVXQPMqPmm2wFdA6JzqIZa+V0A14gzGCr9XQLGPhvVRwldACEF1m5zIV0D6\u002fJ5V59FXQCNCU\u002fPb3VdAKA2Jk77rV0CRQ1blbfpXQPb0cCypCFhAMP8iH08VWED0LmB4lR9YQF2U8m06J1hA3\u002fZuLIgsWEAn3JzunSlYQPg6lMRmKFhAB\u002fkl348oWEAWKkxtiClYQEGJMCXlKlhAqEZSiV4sWECBrbsixC1YQCgmTzv1LlhAFsLRlN8vWEDu+pMFejBYQGeT0u\u002fAMFhA9k4wD7UwWEBwFPAXWjBYQMhK+WK2L1hAYk3CQNQuWECMmPNDwC1YQC1ZDwiILFhAYhjFhDkrWECo1Leo4SlYQFGsT7+LKFhA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=France\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"nAedB54HogekB6UHpgenB6gHqQeqB6sHrQeuB68HsAexB7IHswe0B7UHtge3B7gHuQe7B7oHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"...\u002fM8z\u002fNOQAAAAAAAAElAVVVVVVUVS0DXUF5DeQ1FQFVVVVVVVUdAeXh4eHh4SkCc3vSmN71FQAAAAAAAwEJAAAAAAACARkCc3vSmN71FQNBeQnsJ7UlA11BeQ3kNRUAAAAAAAABQQAAAAAAAgEZA3\u002fSmN73pR0BVVVVVVRVLQN\u002f0pje96UdAjuM4juM4RkAAAAAAAABJQKqqqqqqqkBASZIkSZIkS0Cx3NMIyz1BQGppaWlpaT1AAAAAAABAP0A="},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=France\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"France","showlegend":false,"x":{"dtype":"i2","bdata":"nAedB54HogekB6UHpgenB6gHqQeqB6sHrQeuB68HsAexB7IHswe0B7UHtge3B7gHuQe6B7sHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","b ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="2d1d03c0-a197-4679-875f-122b60d173fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2d1d03c0-a197-4679-875f-122b60d173fd")) {                    Plotly.newPlot(                        "2d1d03c0-a197-4679-875f-122b60d173fd",                        [{"hovertemplate":"Country=Nepal\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nepal","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Nepal","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"pQemB6cHqAepB6oHqwetB64HrwewB7EHsgezB7QHtQe2B7cHuAe5B7sHuge8B70Hvge\u002fB8AHwQfCB8MHxAfFB8YHxwfIB8kHygfLB8wHzQfOB88H0AfRB9IH0wfUB9UH1gfXB9gH2QfaB9sH3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Nepal\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nepal","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Nepal","showlegend":false,"x":{"dtype":"i2","bdata":"pQemB6cHqAepB6oHqwetB64HrwewB7EHsgezB7QHtQe2B7cHuAe5B7oHuwe8B70Hvge\u002fB8AHwQfCB8MHxAfFB8YHxwfIB8kHygfLB8wHzQfOB88H0AfRB9IH0wfUB9UH1gfXB9gH2QfaB9sH3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"VHSVwCKKWUAtPlzgFnxZQEvp+L7DbVlAviDpKiVfWUAPQeWxOVBZQCFHcuICQVlAiK5bLoQxWUAP8w4VwxFZQNcpz46OAVlATfClly3xWEAk8oaCquBYQA8Zr6cQ0FhADRFfB2y\u002fWEAMl07HyK5YQFaYW2QynlhAXSE3ubKNWEAXhqHlUH1YQN1vyqEKbVhALxfB9cZcWEDh+sgmPUxYQARtZt6QPFhARCRmclQtWED\u002f\u002fJnZsB5YQDLrcysOEVhA040pA9IEWEDZfgiOPvpXQGKiTLx88VdAghopUmDgV0DUR8VyftpXQPn\u002fNBEX11dAfrWwPDrWV0AAF0W85tdXQGmVD9kV3FdAfvnJXb3iV0A4Gyav9OtXQJn\u002fV7\u002fs91dA+IUf01MGWEDdDFWzjRZYQO2fAJvgJ1hA\u002fIaNgow5WECELhtY60pYQKetO1OUW1hAsCir1k5oWEDpSOvlXHRYQPWhzz0\u002fgFhAcZvrriCMWEBgKYPLBJhYQI4gq+7jo1hAstGsU7SvWEDyjRmJbLtYQNYmHv8Dx1hAmNyhF3PSWEA+d0Aas91YQOlILSa+6FhAyiqCKI\u002fzWEB7hAJ1Iv5YQAFCrXJ3CFlAhTIGh44SWUAuXgiFaBxZQPIdHsIGJllAyckvKmsvWUD0AU1UmDhZQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=France\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"France","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"nAedB6UHpgenB6gHqQeqB6sHrQeuB68HsAexB7IHswe0B7UHtge3B7gHuQe7B7oHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"\\u002fQA3lNZTXUDpAwzAMwzAMQ0DyGsprKK9HQKqqqqqqqkBAAAAAAAAAOUAkSZIkSZIsQEN5DeU1lC9AAAAAAAAAOUCyEzuxEzszQAAAAAAAAClAh4eHh4eHN0A="},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=France\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#EF553B","symbol":"ci ...

# %% [markdown]
# ### Problem 3
#
# Choose one of the graphs produced above (should match the lecture notes) and discuss what you see there:
#
# 1. Which issue are you focusing on.
# 2. What do the graph axis represent?
# 3. Say in words how the United States votes have changed over time.
# 4. How do the United States votes compare to the other countries?
# 5. See if you can come up with one or two questions that interest you about the data in the graph.

# %% [markdown]
# - I am focusing on Nuclear Wepons and Nuclear Materials.
# - Shows us the percentage of survey responding "yes" throught the years.
# - The support for Nuclera Wepons are going down throught the years.
# - Looks like the US is more aposed to Nucler Wepons then Turky and the UK.
# - Why is Turkeys very much in favor of Nucler Wepons when they are not a strong Nucler Country?

# %% [markdown]
# ### Problem 4
#
# Now go back up to where we picked our three focus countries and choose some different ones. Rerun the analysis. If you want you could choose more than three countries.
#
# Discuss the graph for the same issue but with the new countries.

# %% [markdown]
# Looks like France is on the same boat as US and the apeal for Nuclear Wepon is going down. Its the opposite for Brazil. However Nepal is consistanly in the 100s and I am not sure what that mean.

# %% [markdown]
# --------------------------------
# ### You are done with the homework... now what?
# --------------------------------
#
# 1. Save your changes.
# 2. In the Git tab, **Stage** your changed files - use the (+) button next to the file.
# 3. **Commit** your changes by entering a summary and pushing commit.
# 4. **Push** your changes using the cloud button.
# 5. Check that your changes are on your GitHub repo (online)
# 6. **TAKE THE DAILY QUIZ ON CANVAS** the quiz will ask you to copy and past the HTTPS link to your repo for the day.
# 7. Come to class and get your questions answered.
#
# At the end of the week  you will submit your final versions of the homework on Canvas for grading. For this you can just drag and drop the HW.ipynb files into canvas.
#
# **IMPORTANT** If this is confusing this first week, don't worry, I can help you and I will be really flexible about these first few deadlines.

# %%
Done
